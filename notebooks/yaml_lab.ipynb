# %%
import yaml
from pathlib import Path
import sys
import os
sys.path.append(str(Path(os.path.abspath("..")).resolve()))

# %%
str(Path(os.path.abspath("..")).resolve())
# Out:
# 'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption'

# %%
sys.path
# Out:
# ['C:\\Users\\siran\\AppData\\Roaming\\uv\\python\\cpython-3.12-windows-x86_64-none\\python312.zip',
#  'C:\\Users\\siran\\AppData\\Roaming\\uv\\python\\cpython-3.12-windows-x86_64-none\\DLLs',
#  'C:\\Users\\siran\\AppData\\Roaming\\uv\\python\\cpython-3.12-windows-x86_64-none\\Lib',
#  'c:\\Users\\siran\\ML\\Deep-Learning2\\.venv\\Scripts',
#  'c:\\Users\\siran\\ML\\Deep-Learning2\\.venv',
#  '',
#  'c:\\Users\\siran\\ML\\Deep-Learning2\\.venv\\Lib\\site-packages',
#  'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption',
#  'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption',
#  'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption',
#  'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption',
#  'C:\\Users\\siran\\ML\\Deep-Learning2\\image2caption']

# %%
from src.utils.data import load_yaml

# %%
model_cfg = load_yaml("../config/model.yaml")
encoder_cfg = model_cfg["encoder"]
encoder_cfg
# Out:
# {'conv1': {'in_channels': 3,
#   'out_channels': 16,
#   'kernel_size': 3,
#   'stride': 1,
#   'padding': 1},
#  'pool1': {'kernel_size': 2, 'stride': 1},
#  'conv2': {'in_channels': 16,
#   'out_channels': 5,
#   'kernel_size': 5,
#   'stride': 1,
#   'padding': 1},
#  'pool2': {'kernel_size': 2, 'stride': 1},
#  'conv3': {'in_channels': 5,
#   'out_channels': 3,
#   'kernel_size': 8,
#   'stride': 1,
#   'padding': 1},
#  'pool3': {'kernel_size': 2, 'stride': 1}}

# %%
def encoder_cfg_print(in_channels, out_channels, kernel_size, stride, padding):
    print(in_channels, out_channels, kernel_size, stride, padding)

# %%
encoder_cfg_print(**encoder_cfg["conv2"])
# Out:
# 16 5 5 1 1
