# %%
import torch

# %%
a = torch.tensor(1)

# %%
a.reshape(1,).shape
# Out:
# torch.Size([1])

# %%
b = torch.tensor([1, 4, 3]).reshape(-1, 1)
b, b.shape
# Out:
# (tensor([[1],
#          [4],
#          [3]]),
#  torch.Size([3, 1]))

# %%
torch.max(b.flatten())
# Out:
# tensor(4)

# %%
torch.argmax(b, dim=0)
# Out:
# tensor([1])

# %%
c = torch.zeros_like(b)
c
# Out:
# tensor([[0],
#         [0],
#         [0]])
